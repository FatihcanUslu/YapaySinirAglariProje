# %% [markdown]
# Yalnızca tek bir gizli katman içeren CNN

# %% [markdown]
# Gereksinimler:

# %%
# !pip install numpy
# !pip install tensorflow
# !pip install keras
# !pip install opencv-python
# !pip install pandas

# %% [markdown]
# Veriyi zip'ten çıkarma:

# %%
import zipfile

# zip dosyasının yolu
zip_file_path = "/content/drive/MyDrive/ChestXray.zip"

# zip dosyasını aç
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall("/content/veri")

# %% [markdown]
# Veriyi parçalara bölme:

# %%
import os
import cv2
import numpy as np

def load_data():
    normal_path = '/content/veri/ChestXray/NORMAL'
    pneumonia_path = '/content/veri/ChestXray/PNEUMONIA'
    
    normal_images = []
    pneumonia_images = []
    labels = []
    
    for filename in os.listdir(normal_path):
        img = cv2.imread(os.path.join(normal_path, filename))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        img = cv2.resize(img, (128, 128))
        normal_images.append(img)
        labels.append(0)
        
    for filename in os.listdir(pneumonia_path):
        img = cv2.imread(os.path.join(pneumonia_path, filename))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        img = cv2.resize(img, (128, 128))
        pneumonia_images.append(img)
        labels.append(1)
        
    normal_images = np.array(normal_images)
    pneumonia_images = np.array(pneumonia_images)
    labels = np.array(labels)
    
    return normal_images, pneumonia_images, labels
normal_images,pneumonia_images,labels=load_data()

# %% [markdown]
# Veriyi train-test olarak bölme:

# %%
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Flatten, Dense
from keras.utils import to_categorical

all_images = np.concatenate((normal_images, pneumonia_images))
all_images = np.expand_dims(all_images, axis=-1) # kanal boyutunu ekleyin
all_labels = np.concatenate((np.zeros(len(normal_images)), np.ones(len(pneumonia_images))))
x_train, x_test, y_train, y_test = train_test_split(all_images, all_labels, test_size=0.2)

y_train = to_categorical(y_train, num_classes=2)
y_test = to_categorical(y_test, num_classes=2)

# %% [markdown]
# İleri Beslemeli Sinir Ağı modeli ve eğitim:

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
img_size = (128, 128)#aslinda yanlis cünkü image size değişken bi yapıda

model = Sequential()

model.add(Conv2D(32, (3,3), activation='relu', input_shape=(img_size[0], img_size[1], 1)))
model.add(MaxPooling2D((2,2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(2, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=30, batch_size=32)
# Out:
# Epoch 1/30
# 83/83 [==============================] - 3s 14ms/step - loss: 199.0904 - accuracy: 0.7486 - val_loss: 15.1908 - val_accuracy: 0.9059
# Epoch 2/30
# 83/83 [==============================] - 1s 12ms/step - loss: 7.2961 - accuracy: 0.9271 - val_loss: 57.9234 - val_accuracy: 0.6388
# Epoch 3/30
# 83/83 [==============================] - 1s 13ms/step - loss: 6.2795 - accuracy: 0.9354 - val_loss: 5.6824 - val_accuracy: 0.9317
# Epoch 4/30
# 83/83 [==============================] - 1s 12ms/step - loss: 2.2040 - accuracy: 0.9635 - val_loss: 21.0940 - val_accuracy: 0.7693
# Epoch 5/30
# 83/83 [==============================] - 1s 11ms/step - loss: 7.8812 - accuracy: 0.9237 - val_loss: 6.4400 - val_accuracy: 0.9272
# Epoch 6/30
# 83/83 [==============================] - 1s 12ms/step - loss: 1.5507 - accuracy: 0.9681 - val_loss: 3.9779 - val_accuracy: 0.9378
# Epoch 7/30
# 83/83 [==============================] - 1s 12ms/step - loss: 1.7685 - accuracy: 0.9578 - val_loss: 3.9567 - val_accuracy: 0.9469
# Epoch 8/30
# 83/83 [==============================] - 1s 12ms/step - loss: 0.6900 - accuracy: 0.9814 - val_loss: 4.1741 - val_accuracy: 0.9393
# Epoch 9/30
# 83/83 [==============================] - 1s 11ms/step - loss: 0.1181 - accuracy: 0.9924 - val_loss: 3.8570 - val_accuracy: 0.9423
# Epoch 10/30
# 83/83 [==============================] - 1s 12ms/step - loss: 0.0931 - accuracy: 0.9947 - val_loss: 4.3411 - val_accuracy: 0.9272
# Epoch 11/30
# 83/83 [==============================] - 1s 13ms/step - loss: 0.0743 - accuracy: 0.9966 - val_loss: 4.3489 - val_accuracy: 0.9393
# Epoch 12/30
# 83/83 [==============================] - 1s 13ms/step - loss: 0.0240 - accuracy: 0.9981 - val_loss: 5.1327 - val_accuracy: 0.9317
# Epoch 13/30
# 83/83 [==============================] - 1s 14ms/step - loss: 0.0711 - accuracy: 0.9943 - val_loss: 4.4361 - val_accuracy: 0.9363
# Epoch 14/30
# 83/83 [==============================] - 1s 12ms/step - loss: 0.0201 - accuracy: 0.9985 - val_loss: 6.4071 - val_accuracy: 0.9059
# Epoch 15/30
# 83/83 [==============================] - 1s 12ms/step - loss: 0.0355 - accuracy: 0.9973 - val_loss: 3.5637 - val_accuracy: 0.9454
# Epoch 16/30
# 83/83 [==============================] - 1s 12ms/step - loss: 0.0188 - accuracy: 0.9973 - val_loss: 3.8290 - val_accuracy: 0.9393
# Epoch 17/30
# 83/83 [==============================] - 1s 12ms/step - loss: 0.1694 - accuracy: 0.9928 - val_loss: 3.5994 - val_accuracy: 0.9439
# Epoch 18/30
# 83/83 [==============================] - 1s 11ms/step - loss: 0.0669 - accuracy: 0.9962 - val_loss: 4.0809 - val_accuracy: 0.9317
# Epoch 19/30
# 83/83 [==============================] - 1s 11ms/step - loss: 0.0535 - accuracy: 0.9954 - val_loss: 4.5115 - val_accuracy: 0.9287
# Epoch 20/30
# 83/83 [==============================] - 1s 11ms/step - loss: 0.1113 - accuracy: 0.9951 - val_loss: 3.8253 - val_accuracy: 0.9347
# Epoch 21/30
# 83/83 [==============================] - 1s 11ms/step - loss: 0.0125 - accuracy: 0.9992 - val_loss: 4.1823 - val_accuracy: 0.9378
# Epoch 22/30
# 83/83 [==============================] - 1s 12ms/step - loss: 0.0193 - accuracy: 0.9985 - val_loss: 3.8074 - val_accuracy: 0.9347
# Epoch 23/30
# 83/83 [==============================] - 1s 11ms/step - loss: 0.0283 - accuracy: 0.9981 - val_loss: 3.4749 - val_accuracy: 0.9363
# Epoch 24/30
# 83/83 [==============================] - 1s 14ms/step - loss: 0.0465 - accuracy: 0.9973 - val_loss: 3.9610 - val_accuracy: 0.9363
# Epoch 25/30
# 83/83 [==============================] - 1s 13ms/step - loss: 0.1743 - accuracy: 0.9920 - val_loss: 20.9377 - val_accuracy: 0.7769
# Epoch 26/30
# 83/83 [==============================] - 1s 14ms/step - loss: 1.3626 - accuracy: 0.9708 - val_loss: 5.0432 - val_accuracy: 0.9241
# Epoch 27/30
# 83/83 [==============================] - 1s 12ms/step - loss: 0.0986 - accuracy: 0.9947 - val_loss: 3.1963 - val_accuracy: 0.9347
# Epoch 28/30
# 83/83 [==============================] - 1s 12ms/step - loss: 0.0289 - accuracy: 0.9989 - val_loss: 3.7467 - val_accuracy: 0.9393
# Epoch 29/30
# 83/83 [==============================] - 1s 12ms/step - loss: 0.0649 - accuracy: 0.9954 - val_loss: 3.3430 - val_accuracy: 0.9454
# Epoch 30/30
# 83/83 [==============================] - 1s 12ms/step - loss: 0.0219 - accuracy: 0.9985 - val_loss: 3.1640 - val_accuracy: 0.9211

# %% [markdown]
# Loss-Accuracy tablosu:

# %%
import pandas as pd
df = pd.DataFrame(model.history.history)
loss=df.drop(["accuracy","val_accuracy"],axis=1)
accuracy=df.drop(["loss","val_loss"],axis=1)
loss.plot()
accuracy.plot()
# Out:
# <Axes: >

# %% [markdown]
# Test:

# %%
loss, accuracy = model.evaluate(x_test, y_test)
print('Test Loss:', loss)
print('Test Accuracy:', accuracy)
# Out:
# 21/21 [==============================] - 0s 4ms/step - loss: 3.1640 - accuracy: 0.9211
# Test Loss: 3.164019823074341
# Test Accuracy: 0.9210925698280334
